# %% [markdown]
# # 1.Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('honeyproduction.csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.shape
# Out:
# (626, 8)

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %% [raw]
# Features:
#
# dataframe is in 'pandas.core.frame.DataFrame' format
# there are total of 626 entries
# 8 columns in a dataframe
# in 8 columns all are non null values
# column which is having name 'state' is a object values
# column which is having name 'yieldperpool' is a int values
# columns which are remaining are float values

# %% [markdown]
# # 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
year = df['year'].value_counts()
year

plt.pie(df.year.value_counts(), autopct = '%.2f%%', radius = 1.1,labels=year.index)
plt.title('Distribution of data in each year')

plt.show()

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(df["priceperlb"])
plt.title('Distribution of price per lb')

plt.show()

# %% [raw]
# Findings:
#
# data of price per lb is right skewed
# at 1.4 of price per lb ,there is count found nearer to 100

# %% [markdown]
# # 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
x=df["numcol"]
y=df["prodvalue"]
plt.scatter(x,y)
plt.title('scatterplot betweem numcol and product value')

plt. xlabel('numcol')
plt.ylabel('product value')
plt.show()

# %% [raw]
# Findings:
#
# numcol and product value are  positively related to each other
# as numcol increases product value also increases

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
sns.boxplot(data=df,x='year',y='prodvalue')
plt.title("Relationship between 'year' and 'product value'")
plt.show()

# %% [raw]
# Findings:
#
# The position of the box along the y-axis provides an understanding of the median 'product value' per year.
# we can compare the medians across different years to identify changes over time.

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
columns=["numcol",'yieldpercol','totalprod','prodvalue','year']
data=df[columns]
sns.pairplot(data,hue="year")
plt.show()

# %% [raw]
# Year-wise variations By using the 'hue' parameter in the pairplot.
# we can observe the relationship between variables for different years.
# we see the positive relation between numcol and total production through all years
# we see the positive relation between numcol and total product value through all years
# In all the years the data right skewed

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
columns = ['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']
data = df[columns]
data.corr()
sns.heatmap(data.corr(), annot=True )
plt.title('Correlation Matrix of the given data')
plt.show()

# %%
df[columns].corr()# normal correlation values,without using plot
# Out:
#                numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701   0.912796
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646   0.278977
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499   0.907236
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867   0.728560
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000  -0.089567
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567   1.000000
